# %% [markdown]
# # TABELLA GLOSSARIO SIOPE REGIONALE 2013-2014
# <br>
# http://www.rgs.mef.gov.it/_Documenti/VERSIONE-I/e-GOVERNME1/SIOPE/Glossario-/Glossario_SIOPE_Region2013.xls
# <br>
# <br>
# PER UTILIZZO CON database SQLITE di Matteo Fortini
# <br>
# https://github.com/mfortini/soldipubblici
# <br>
# <br>
# <a href = "https://github.com/scarsellifi/normalizzazione-glossari-siope/blob/master/raccordo_codici_regionale.xlsx?raw=true" target="_blank">OUTPUT </a>
# <br>
# <br>
# ESEMPIO DI UTILIZZO
# <br>
# Ottenere il bilancio aggregato per livello di codice bilancio

# %% [markdown]
# ## Esempio di risultati

# %%
# AGGREGAZIONE PER CODICE BILANCIO I CIFRA
# Out:
#                                             imp_uscite_att      importo_2013  \
# DESCRIZIONI VOCI livello1
# TITOLO 1°: SPESE CORRENTI                 3,070,248,175.93 38,323,801,514.22
# TITOLO 2°: SPESE IN CONTO CAPITALE        1,186,949,500.45 14,229,380,327.79
# TITOLO 3°: SPESE PER RIMBORSO DI PRESTITI    53,135,929.52    569,918,547.29
#
#                                                importo_2014
# DESCRIZIONI VOCI livello1
# TITOLO 1°: SPESE CORRENTI                 36,185,315,346.58
# TITOLO 2°: SPESE IN CONTO CAPITALE        11,315,236,477.59
# TITOLO 3°: SPESE PER RIMBORSO DI PRESTITI    512,074,515.05

# %%
# AGGREGAZIONE PER CODICE BILANCIO II-III CIFRA
# Out:
#                                                                imp_uscite_att  \
# DESCRIZIONI VOCI livello2
# CONCESSIONI DI CREDITI E ANTICIPAZIONI                         164,414,172.31
# INTERESSI PASSIVI E ONERI FINANZIARI DIVERSI                   306,846,971.16
# INVESTIMENTI FISSI                                             221,885,361.07
# PERSONALE                                                      418,506,757.71
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico della regione)       53,135,929.52
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico dello Stato)                  0.00
# TRASFERIMENTI CORRENTI AD ALTRI SOGGETTI                       312,401,498.03
# TRASFERIMENTI CORRENTI AD AMMINISTRAZIONI PUBBLICHE          2,032,492,949.03
# TRASFERIMENTI IN CONTO CAPITALE AD ALTRI SOGGETTI              318,140,906.02
# TRASFERIMENTI IN CONTO CAPITALE AD AMMINISTRAZIONI PUBBLICHE   482,509,061.05
#
#                                                                   importo_2013  \
# DESCRIZIONI VOCI livello2
# CONCESSIONI DI CREDITI E ANTICIPAZIONI                          486,783,213.94
# INTERESSI PASSIVI E ONERI FINANZIARI DIVERSI                  1,748,843,006.01
# INVESTIMENTI FISSI                                            2,379,273,141.10
# PERSONALE                                                     6,034,383,751.42
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico della regione)       525,706,393.00
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico dello Stato)          44,212,154.29
# TRASFERIMENTI CORRENTI AD ALTRI SOGGETTI                      3,956,383,936.17
# TRASFERIMENTI CORRENTI AD AMMINISTRAZIONI PUBBLICHE          26,584,190,820.62
# TRASFERIMENTI IN CONTO CAPITALE AD ALTRI SOGGETTI             4,302,089,225.40
# TRASFERIMENTI IN CONTO CAPITALE AD AMMINISTRAZIONI PUBBLICHE  7,061,234,747.35
#
#                                                                   importo_2014
# DESCRIZIONI VOCI livello2
# CONCESSIONI DI CREDITI E ANTICIPAZIONI                          575,527,903.31
# INTERESSI PASSIVI E ONERI FINANZIARI DIVERSI                  1,462,613,739.08
# INVESTIMENTI FISSI                                            2,387,077,892.26
# PERSONALE                                                     5,195,446,847.98
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico della regione)       483,292,770.62
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico dello Stato)          28,781,744.43
# TRASFERIMENTI CORRENTI AD ALTRI SOGGETTI                      3,506,484,146.08
# TRASFERIMENTI CORRENTI AD AMMINISTRAZIONI PUBBLICHE          26,020,770,613.44
# TRASFERIMENTI IN CONTO CAPITALE AD ALTRI SOGGETTI             3,068,641,969.53
# TRASFERIMENTI IN CONTO CAPITALE AD AMMINISTRAZIONI PUBBLICHE  5,283,988,712.49

# %%
# AGGREGAZIONE PER CODICE BILANCIO IV-V CIFRA
# Out:
#                                                                         imp_uscite_att  \
# DESCRIZIONI VOCI livello3
# Altre spese per il personale                                             12,922,244.68
# Beni immobili                                                           199,195,746.89
# Beni mobili                                                              10,216,054.02
# Concessioni di crediti a Enti delle Amministrazioni pubbliche            43,387,671.97
# Concessioni di crediti a imprese                                        121,026,500.34
# Contributi effettivi a carico dell'ente                                  74,241,618.67
# Interessi passivi a Cassa depositi e prestiti a carico della Regione              0.00
# Interessi passivi a Cassa depositi e prestiti a carico dello Stato                0.00
# Interessi passivi ad altri soggetti a carico della Regione              306,846,971.16
# Interessi passivi ad altri soggetti a carico dello Stato                          0.00
# Interventi assistenziali                                                    133,097.66
# Oneri per il personale in quiescenza                                     53,829,554.43
# Prodotti informatici                                                     12,473,560.16
# Retribuzioni lorde                                                      277,380,242.27
# Rimborso di altri prestiti obbligazionari (a carico della regione)       11,873,589.40
# Rimborso di altri prestiti obbligazionari (a carico dello Stato)                  0.00
# Rimborso di prestiti di BOR (a carico della regione)                     41,262,340.12
# Titoli                                                                            0.00
# Trasferimenti correnti  a Imprese                                       200,505,662.89
# Trasferimenti correnti  ad Enti delle Amministrazioni locali          2,009,534,011.30
# Trasferimenti correnti ad Enti dell'Amministrazione centrale             22,958,937.73
# Trasferimenti correnti ad altri soggetti                                110,130,942.62
# Trasferimenti correnti all'estero                                         1,764,892.52
# Trasferimenti in conto capitale  a Enti dell'Amministrazione centrale    37,604,767.20
# Trasferimenti in conto capitale  a Enti delle Amministrazioni locali    444,904,293.85
# Trasferimenti in conto capitale a Imprese                               294,119,576.26
# Trasferimenti in conto capitale a Istituzioni estere                        435,514.67
# Trasferimenti in conto capitale ad altri soggetti                        23,585,815.09
#
#                                                                            importo_2013  \
# DESCRIZIONI VOCI livello3
# Altre spese per il personale                                             153,329,765.19
# Beni immobili                                                          1,956,074,509.48
# Beni mobili                                                              132,438,525.46
# Concessioni di crediti a Enti delle Amministrazioni pubbliche            371,855,300.99
# Concessioni di crediti a imprese                                         114,927,912.95
# Contributi effettivi a carico dell'ente                                1,124,822,975.47
# Interessi passivi a Cassa depositi e prestiti a carico della Regione     335,735,101.60
# Interessi passivi a Cassa depositi e prestiti a carico dello Stato        82,885,346.94
# Interessi passivi ad altri soggetti a carico della Regione             1,261,095,436.18
# Interessi passivi ad altri soggetti a carico dello Stato                  69,127,121.29
# Interventi assistenziali                                                   7,513,036.08
# Oneri per il personale in quiescenza                                     674,274,659.02
# Prodotti informatici                                                     185,590,054.71
# Retribuzioni lorde                                                     4,074,443,315.66
# Rimborso di altri prestiti obbligazionari (a carico della regione)       141,363,953.66
# Rimborso di altri prestiti obbligazionari (a carico dello Stato)          44,212,154.29
# Rimborso di prestiti di BOR (a carico della regione)                     384,342,439.34
# Titoli                                                                   105,170,051.45
# Trasferimenti correnti  a Imprese                                      2,158,866,753.33
# Trasferimenti correnti  ad Enti delle Amministrazioni locali          25,866,011,702.34
# Trasferimenti correnti ad Enti dell'Amministrazione centrale             718,179,118.28
# Trasferimenti correnti ad altri soggetti                               1,782,031,301.01
# Trasferimenti correnti all'estero                                         15,485,881.83
# Trasferimenti in conto capitale  a Enti dell'Amministrazione centrale    708,315,146.61
# Trasferimenti in conto capitale  a Enti delle Amministrazioni locali   6,352,919,600.74
# Trasferimenti in conto capitale a Imprese                              3,712,864,899.23
# Trasferimenti in conto capitale a Istituzioni estere                      28,685,451.24
# Trasferimenti in conto capitale ad altri soggetti                        560,538,874.93
#
#                                                                            importo_2014
# DESCRIZIONI VOCI livello3
# Altre spese per il personale                                             137,292,675.81
# Beni immobili                                                          2,072,494,390.50
# Beni mobili                                                              125,877,621.71
# Concessioni di crediti a Enti delle Amministrazioni pubbliche            315,607,245.31
# Concessioni di crediti a imprese                                         259,920,658.00
# Contributi effettivi a carico dell'ente                                  927,059,209.98
# Interessi passivi a Cassa depositi e prestiti a carico della Regione     175,608,984.99
# Interessi passivi a Cassa depositi e prestiti a carico dello Stato        29,919,563.97
# Interessi passivi ad altri soggetti a carico della Regione             1,209,620,222.97
# Interessi passivi ad altri soggetti a carico dello Stato                  47,464,967.15
# Interventi assistenziali                                                   6,622,204.42
# Oneri per il personale in quiescenza                                     609,610,595.79
# Prodotti informatici                                                     150,614,539.55
# Retribuzioni lorde                                                     3,514,862,161.98
# Rimborso di altri prestiti obbligazionari (a carico della regione)       125,560,267.54
# Rimborso di altri prestiti obbligazionari (a carico dello Stato)          28,781,744.43
# Rimborso di prestiti di BOR (a carico della regione)                     357,732,503.08
# Titoli                                                                    38,091,340.50
# Trasferimenti correnti  a Imprese                                      1,975,903,739.68
# Trasferimenti correnti  ad Enti delle Amministrazioni locali          25,806,213,280.11
# Trasferimenti correnti ad Enti dell'Amministrazione centrale             214,557,333.33
# Trasferimenti correnti ad altri soggetti                               1,510,157,593.60
# Trasferimenti correnti all'estero                                         20,422,812.80
# Trasferimenti in conto capitale  a Enti dell'Amministrazione centrale    358,005,718.24
# Trasferimenti in conto capitale  a Enti delle Amministrazioni locali   4,925,982,994.25
# Trasferimenti in conto capitale a Imprese                              2,575,308,041.53
# Trasferimenti in conto capitale a Istituzioni estere                      28,288,737.71
# Trasferimenti in conto capitale ad altri soggetti                        465,045,190.29

# %% [markdown]
# # CODICE

# %%
import os
import pandas as pd
import numpy as np
import math

# %%
# CAMBIARE LA DIRECTORY IMPOSTANDO L'INDIRIZZO SU QUELLO DOVE E' COLLOCATO IL GLOSSARIO SIOPER PER LE REGIONI 2013
os.chdir(r"E:\Dropbox\Dropbox\librerie\GLOSSARI_SIOPE")

# %%
#os.listdir(r"E:\Dropbox\Dropbox\librerie\Siope")

# %%
def ricodifica(x):
    if x == "":
        return ""
    else:
        return str(x)
        
def ricodifica2(x):
    try:
        if math.isnan(float(x)):
            return ""
        else:
            return "-" + str(int(x))
    except:
        return ""

# %%
codici_regionali = pd.read_excel('Glossario_SIOPE_Region2013.xls', "SPESE", skiprows = 5)

# %%
codici_regionali_1 = codici_regionali 
codici_regionali_1.fillna("", inplace = True)

# %%
codici_regionali_1["CODICI GESTIONALI_5digit"] = codici_regionali_1["CODICE BILANCIO"].apply(lambda x: ricodifica(x)) \
 + codici_regionali_1["Unnamed: 1"].apply(lambda x: ricodifica(x)) + codici_regionali_1["Unnamed: 2"].apply(lambda x: ricodifica(x)) #+ \
    #codici_regionali_1["CODICI GESTIONALI"].apply(lambda x: ricodifica2(x))

# %%
codici_regionali_1_ridotto =  codici_regionali_1.iloc[1:,:]

# %%
codici_regionali_1_ridotto2 = codici_regionali_1_ridotto[codici_regionali_1_ridotto["CODICI GESTIONALI_5digit"] != ""]

# %%
#codici_regionali_1_ridotto2

# %%
codici_regionali_1_ridotto2.columns = [u'CODICE BILANCIO I digit', u'CODICE BILANCIO II-III digit', u'CODICE BILANCIO IV-V digit', 
                                       u'CODICI GESTIONALI', u'DESCRIZIONI VOCI', u'DESCRIZIONI VOCI 5 digit',
                                       u'DEFINIZIONI 5 digit', u'CODICI raccordo_5digit']

# %%
codici_bilancio4 = codici_regionali_1_ridotto2[codici_regionali_1_ridotto2["CODICI GESTIONALI"] != ""]

codici_bilancio4["CODICI raccordo livello 1"] = codici_bilancio4["CODICI raccordo_5digit"].map(lambda x: x[0])
codici_bilancio4["CODICI raccordo livello 2"] = codici_bilancio4["CODICI raccordo_5digit"].map(lambda x: x[0:3])
codici_bilancio4["CODICI raccordo livello 3"] = codici_bilancio4["CODICI raccordo_5digit"].map(lambda x: x)

# %%
#codici_bilancio4

# %%
codici_bilancioI_II_III = codici_regionali_1_ridotto2[codici_regionali_1_ridotto2["CODICI GESTIONALI"] == ""]

# %%
codici_bilancioI_II_III_ridotto = codici_bilancioI_II_III[["CODICI raccordo_5digit", "DESCRIZIONI VOCI", "DEFINIZIONI 5 digit"]]

# %%
codici_bilancioI_II_III_ridotto.columns = [u'CODICI', u'DESCRIZIONI VOCI', u'DEFINIZIONI']

# %%
#codici_bilancioI_II_III_ridotto

# %%
PassaggioI = pd.merge(codici_bilancio4, codici_bilancioI_II_III_ridotto, left_on = "CODICI raccordo livello 1", right_on = "CODICI", suffixes = ("", " livello1"), )
PassaggioII = pd.merge(PassaggioI, codici_bilancioI_II_III_ridotto, left_on = "CODICI raccordo livello 2", right_on = "CODICI", suffixes = ("", " livello2"), )
PassaggioIII = pd.merge(PassaggioII, codici_bilancioI_II_III_ridotto, left_on = "CODICI raccordo livello 3", right_on = "CODICI", suffixes = ("", " livello3"), )

# %%
raccordo_codici_regionale = PassaggioIII

# %%
raccordo_codici_regionale["CODICI GESTIONALI"] = raccordo_codici_regionale["CODICI GESTIONALI"].map(lambda x: unicode(x)[:-2])

# %%
raccordo_codici_regionale.to_excel("raccordo_codici_regionale.xlsx")

# %% [markdown]
# # Esempio di utilizzo con i dati regionali

# %%
#CAMBIARE CON LA CARTELLA NELLA QUALE RISIEDE IL FILE SQLITE

import sqlite3

SIOPE = r"E:\Dropbox\Dropbox\A_dati\SIOPE"

db = os.path.join(SIOPE, "allSIOPE_2014-12-22.sqlite3")

# %%
con = sqlite3.connect(db)
cursor = con.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [(u'codici_siope',), (u'importi',), (u'comuniSIOPE',), (u'codici_enti',), (u'comuniSIOPEcsv',)]

# %%
importi = pd.read_sql('SELECT * from importi', con)
codici_enti = pd.read_sql('SELECT * from codici_enti', con)

# %%
importo_ente = pd.merge(importi, codici_enti, left_on = "codice_ente", right_on = "codice")

regioni = importo_ente[importo_ente["codice_sottocomparto"] == u'REGIONE']

# %%
regione_importo_ente_descrizione = pd.merge(regioni, raccordo_codici_regionale, left_on = "codice_siope", right_on = "CODICI GESTIONALI")

# %%
regione_importo_ente_descrizione["imp_uscite_att"] = regione_importo_ente_descrizione["imp_uscite_att"] / 100

regione_importo_ente_descrizione["importo_2013"] = regione_importo_ente_descrizione["importo_2013"] / 100

regione_importo_ente_descrizione["importo_2014"] = regione_importo_ente_descrizione["importo_2014"] / 100

#regione_importo_ente_descrizione

# %%
pd.options.display.float_format = '{:,.2f}'.format

regione_importo_ente_descrizione.groupby("DESCRIZIONI VOCI livello1").sum()[["imp_uscite_att", "importo_2013", "importo_2014"]]
# Out:
#                                             imp_uscite_att      importo_2013  \
# DESCRIZIONI VOCI livello1
# TITOLO 1°: SPESE CORRENTI                 3,070,248,175.93 38,323,801,514.22
# TITOLO 2°: SPESE IN CONTO CAPITALE        1,186,949,500.45 14,229,380,327.79
# TITOLO 3°: SPESE PER RIMBORSO DI PRESTITI    53,135,929.52    569,918,547.29
#
#                                                importo_2014
# DESCRIZIONI VOCI livello1
# TITOLO 1°: SPESE CORRENTI                 36,185,315,346.58
# TITOLO 2°: SPESE IN CONTO CAPITALE        11,315,236,477.59
# TITOLO 3°: SPESE PER RIMBORSO DI PRESTITI    512,074,515.05

# %%
regione_importo_ente_descrizione.groupby("DESCRIZIONI VOCI livello2").sum()[["imp_uscite_att", "importo_2013", "importo_2014"]]
# Out:
#                                                                imp_uscite_att  \
# DESCRIZIONI VOCI livello2
# CONCESSIONI DI CREDITI E ANTICIPAZIONI                         164,414,172.31
# INTERESSI PASSIVI E ONERI FINANZIARI DIVERSI                   306,846,971.16
# INVESTIMENTI FISSI                                             221,885,361.07
# PERSONALE                                                      418,506,757.71
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico della regione)       53,135,929.52
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico dello Stato)                  0.00
# TRASFERIMENTI CORRENTI AD ALTRI SOGGETTI                       312,401,498.03
# TRASFERIMENTI CORRENTI AD AMMINISTRAZIONI PUBBLICHE          2,032,492,949.03
# TRASFERIMENTI IN CONTO CAPITALE AD ALTRI SOGGETTI              318,140,906.02
# TRASFERIMENTI IN CONTO CAPITALE AD AMMINISTRAZIONI PUBBLICHE   482,509,061.05
#
#                                                                   importo_2013  \
# DESCRIZIONI VOCI livello2
# CONCESSIONI DI CREDITI E ANTICIPAZIONI                          486,783,213.94
# INTERESSI PASSIVI E ONERI FINANZIARI DIVERSI                  1,748,843,006.01
# INVESTIMENTI FISSI                                            2,379,273,141.10
# PERSONALE                                                     6,034,383,751.42
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico della regione)       525,706,393.00
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico dello Stato)          44,212,154.29
# TRASFERIMENTI CORRENTI AD ALTRI SOGGETTI                      3,956,383,936.17
# TRASFERIMENTI CORRENTI AD AMMINISTRAZIONI PUBBLICHE          26,584,190,820.62
# TRASFERIMENTI IN CONTO CAPITALE AD ALTRI SOGGETTI             4,302,089,225.40
# TRASFERIMENTI IN CONTO CAPITALE AD AMMINISTRAZIONI PUBBLICHE  7,061,234,747.35
#
#                                                                   importo_2014
# DESCRIZIONI VOCI livello2
# CONCESSIONI DI CREDITI E ANTICIPAZIONI                          575,527,903.31
# INTERESSI PASSIVI E ONERI FINANZIARI DIVERSI                  1,462,613,739.08
# INVESTIMENTI FISSI                                            2,387,077,892.26
# PERSONALE                                                     5,195,446,847.98
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico della regione)       483,292,770.62
# RIMBORSO PRESTITI OBBLIGAZIONARI (a carico dello Stato)          28,781,744.43
# TRASFERIMENTI CORRENTI AD ALTRI SOGGETTI                      3,506,484,146.08
# TRASFERIMENTI CORRENTI AD AMMINISTRAZIONI PUBBLICHE          26,020,770,613.44
# TRASFERIMENTI IN CONTO CAPITALE AD ALTRI SOGGETTI             3,068,641,969.53
# TRASFERIMENTI IN CONTO CAPITALE AD AMMINISTRAZIONI PUBBLICHE  5,283,988,712.49

# %%
regione_importo_ente_descrizione.groupby("DESCRIZIONI VOCI livello3").sum()[["imp_uscite_att", "importo_2013", "importo_2014"]]
# Out:
#                                                                         imp_uscite_att  \
# DESCRIZIONI VOCI livello3
# Altre spese per il personale                                             12,922,244.68
# Beni immobili                                                           199,195,746.89
# Beni mobili                                                              10,216,054.02
# Concessioni di crediti a Enti delle Amministrazioni pubbliche            43,387,671.97
# Concessioni di crediti a imprese                                        121,026,500.34
# Contributi effettivi a carico dell'ente                                  74,241,618.67
# Interessi passivi a Cassa depositi e prestiti a carico della Regione              0.00
# Interessi passivi a Cassa depositi e prestiti a carico dello Stato                0.00
# Interessi passivi ad altri soggetti a carico della Regione              306,846,971.16
# Interessi passivi ad altri soggetti a carico dello Stato                          0.00
# Interventi assistenziali                                                    133,097.66
# Oneri per il personale in quiescenza                                     53,829,554.43
# Prodotti informatici                                                     12,473,560.16
# Retribuzioni lorde                                                      277,380,242.27
# Rimborso di altri prestiti obbligazionari (a carico della regione)       11,873,589.40
# Rimborso di altri prestiti obbligazionari (a carico dello Stato)                  0.00
# Rimborso di prestiti di BOR (a carico della regione)                     41,262,340.12
# Titoli                                                                            0.00
# Trasferimenti correnti  a Imprese                                       200,505,662.89
# Trasferimenti correnti  ad Enti delle Amministrazioni locali          2,009,534,011.30
# Trasferimenti correnti ad Enti dell'Amministrazione centrale             22,958,937.73
# Trasferimenti correnti ad altri soggetti                                110,130,942.62
# Trasferimenti correnti all'estero                                         1,764,892.52
# Trasferimenti in conto capitale  a Enti dell'Amministrazione centrale    37,604,767.20
# Trasferimenti in conto capitale  a Enti delle Amministrazioni locali    444,904,293.85
# Trasferimenti in conto capitale a Imprese                               294,119,576.26
# Trasferimenti in conto capitale a Istituzioni estere                        435,514.67
# Trasferimenti in conto capitale ad altri soggetti                        23,585,815.09
#
#                                                                            importo_2013  \
# DESCRIZIONI VOCI livello3
# Altre spese per il personale                                             153,329,765.19
# Beni immobili                                                          1,956,074,509.48
# Beni mobili                                                              132,438,525.46
# Concessioni di crediti a Enti delle Amministrazioni pubbliche            371,855,300.99
# Concessioni di crediti a imprese                                         114,927,912.95
# Contributi effettivi a carico dell'ente                                1,124,822,975.47
# Interessi passivi a Cassa depositi e prestiti a carico della Regione     335,735,101.60
# Interessi passivi a Cassa depositi e prestiti a carico dello Stato        82,885,346.94
# Interessi passivi ad altri soggetti a carico della Regione             1,261,095,436.18
# Interessi passivi ad altri soggetti a carico dello Stato                  69,127,121.29
# Interventi assistenziali                                                   7,513,036.08
# Oneri per il personale in quiescenza                                     674,274,659.02
# Prodotti informatici                                                     185,590,054.71
# Retribuzioni lorde                                                     4,074,443,315.66
# Rimborso di altri prestiti obbligazionari (a carico della regione)       141,363,953.66
# Rimborso di altri prestiti obbligazionari (a carico dello Stato)          44,212,154.29
# Rimborso di prestiti di BOR (a carico della regione)                     384,342,439.34
# Titoli                                                                   105,170,051.45
# Trasferimenti correnti  a Imprese                                      2,158,866,753.33
# Trasferimenti correnti  ad Enti delle Amministrazioni locali          25,866,011,702.34
# Trasferimenti correnti ad Enti dell'Amministrazione centrale             718,179,118.28
# Trasferimenti correnti ad altri soggetti                               1,782,031,301.01
# Trasferimenti correnti all'estero                                         15,485,881.83
# Trasferimenti in conto capitale  a Enti dell'Amministrazione centrale    708,315,146.61
# Trasferimenti in conto capitale  a Enti delle Amministrazioni locali   6,352,919,600.74
# Trasferimenti in conto capitale a Imprese                              3,712,864,899.23
# Trasferimenti in conto capitale a Istituzioni estere                      28,685,451.24
# Trasferimenti in conto capitale ad altri soggetti                        560,538,874.93
#
#                                                                            importo_2014
# DESCRIZIONI VOCI livello3
# Altre spese per il personale                                             137,292,675.81
# Beni immobili                                                          2,072,494,390.50
# Beni mobili                                                              125,877,621.71
# Concessioni di crediti a Enti delle Amministrazioni pubbliche            315,607,245.31
# Concessioni di crediti a imprese                                         259,920,658.00
# Contributi effettivi a carico dell'ente                                  927,059,209.98
# Interessi passivi a Cassa depositi e prestiti a carico della Regione     175,608,984.99
# Interessi passivi a Cassa depositi e prestiti a carico dello Stato        29,919,563.97
# Interessi passivi ad altri soggetti a carico della Regione             1,209,620,222.97
# Interessi passivi ad altri soggetti a carico dello Stato                  47,464,967.15
# Interventi assistenziali                                                   6,622,204.42
# Oneri per il personale in quiescenza                                     609,610,595.79
# Prodotti informatici                                                     150,614,539.55
# Retribuzioni lorde                                                     3,514,862,161.98
# Rimborso di altri prestiti obbligazionari (a carico della regione)       125,560,267.54
# Rimborso di altri prestiti obbligazionari (a carico dello Stato)          28,781,744.43
# Rimborso di prestiti di BOR (a carico della regione)                     357,732,503.08
# Titoli                                                                    38,091,340.50
# Trasferimenti correnti  a Imprese                                      1,975,903,739.68
# Trasferimenti correnti  ad Enti delle Amministrazioni locali          25,806,213,280.11
# Trasferimenti correnti ad Enti dell'Amministrazione centrale             214,557,333.33
# Trasferimenti correnti ad altri soggetti                               1,510,157,593.60
# Trasferimenti correnti all'estero                                         20,422,812.80
# Trasferimenti in conto capitale  a Enti dell'Amministrazione centrale    358,005,718.24
# Trasferimenti in conto capitale  a Enti delle Amministrazioni locali   4,925,982,994.25
# Trasferimenti in conto capitale a Imprese                              2,575,308,041.53
# Trasferimenti in conto capitale a Istituzioni estere                      28,288,737.71
# Trasferimenti in conto capitale ad altri soggetti                        465,045,190.29
